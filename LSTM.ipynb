# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dropout,Dense
import yfinance as yf
crypt = 'BTC-USD'
start_date = "2019-01-01"
end_date = "2024-01-01"
df = yf.download(crypt, start=start_date, end=end_date)
print(df)
# Out:
# WARNING:tensorflow:From C:\Users\athar\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2019-01-01   3746.713379   3850.913818   3707.231201   3843.520020
# 2019-01-02   3849.216309   3947.981201   3817.409424   3943.409424
# 2019-01-03   3931.048584   3935.685059   3826.222900   3836.741211
# 2019-01-04   3832.040039   3865.934570   3783.853760   3857.717529
# 2019-01-05   3851.973877   3904.903076   3836.900146   3845.194580
# ...                  ...           ...           ...           ...
# 2023-12-27  42518.468750  43683.160156  42167.582031  43442.855469
# 2023-12-28  43468.199219  43804.781250  42318.550781  42627.855469
# 2023-12-29  42614.644531  43124.324219  41424.062500  42099.402344
# 2023-12-30  42091.753906  42584.125000  41556.226562  42156.902344
# 2023-12-31  42152.097656  42860.937500  41998.253906  42265.187500
#
#                Adj Close       Volume
# Date
# 2019-01-01   3843.520020   4324200990
# 2019-01-02   3943.409424   5244856836
# 2019-01-03   3836.741211   4530215219
# 2019-01-04   3857.717529   4847965467
# 2019-01-05   3845.194580   5137609824
# ...                  ...          ...
# 2023-12-27  43442.855469  25260941032
# 2023-12-28  42627.855469  22992093014
# 2023-12-29  42099.402344  26000021055
# 2023-12-30  42156.902344  16013925945
# 2023-12-31  42265.187500  16397498810
#
# [1826 rows x 6 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'],label='Original Bitcoin Price')
plt.title('Bitcoin Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
dataset = df['Close']
dataset = pd.DataFrame(dataset)
data = dataset.values
data.shape
# Out:
# (1826, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data))
training_data = int(len(data)*0.8)
testing_data = int(len(data)-training_data)
print('Training data:',training_data,'Testing data:',testing_data)
# Out:
# Training data: 1460 Testing data: 366

# %%
train_data = scaled_data[0:training_data,:]
train_data.shape
# Out:
# (1460, 1)

# %%
X_train = []
Y_train = []
cols = 1
for i in range(60,len(train_data)):
    X_train.append(train_data[i-60:i,:cols])
    Y_train.append(train_data[i,:cols])
    if i<=60:
        print('X_train:',X_train)
        print('Y_train:',Y_train)
X_train, Y_train = np.array(X_train), np.array(Y_train)
# Out:
# X_train: [array([[0.00692016],
#        [0.00847686],
#        [0.00681452],
#        [0.00714142],
#        [0.00694626],
#        [0.01055304],
#        [0.00975226],
#        [0.00983952],
#        [0.00990885],
#        [0.00435506],
#        [0.00448661],
#        [0.00408041],
#        [0.00239189],
#        [0.00477783],
#        [0.00360313],
#        [0.00398232],
#        [0.00434944],
#        [0.00402647],
#        [0.00512872],
#        [0.00314088],
#        [0.00275157],
#        [0.00319641],
#        [0.00289324],
#        [0.00313857],
#        [0.00312143],
#        [0.00316343],
#        [0.0028752 ],
#        [0.00110615],
#        [0.0007581 ],
#        [0.00135131],
#        [0.00090889],
#        [0.0013788 ],
#        [0.00189487],
#        [0.00100583],
#        [0.0009301 ],
#        [0.00104236],
#        [0.00022279],
#        [0.        ],
#        [0.0041658 ],
#        [0.00423474],
#        [0.0045306 ],
#        [0.00387984],
#        [0.00395929],
#        [0.00362488],
#        [0.00338816],
#        [0.0034494 ],
#        [0.0035893 ],
#        [0.00427576],
#        [0.00804525],
#        [0.00853429],
#        [0.00935599],
#        [0.00864375],
#        [0.00944491],
#        [0.01157996],
#        [0.00640444],
#        [0.00753069],
#        [0.00708906],
#        [0.00703747],
#        [0.00709572],
#        [0.0071705 ]])]
# Y_train: [array([0.00724579])]

# %%
X_train = np.reshape(X_train,(X_train.shape[0],X_train.shape[1],cols))
X_train.shape,Y_train.shape
# Out:
# ((1400, 60, 1), (1400, 1))

# %%
model = Sequential([    
    LSTM(units = 50,return_sequences = True,input_shape = (X_train.shape[1],cols)),
    LSTM(units = 64,return_sequences = False),
    Dense(units = 32),
    Dense(units = 16),
    Dense(units = cols)
])
model.compile(optimizer='adam',loss='mse')
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\athar\anaconda3\Lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\athar\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42465 (165.88 KB)
# Trainable params: 42465 (165.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train,Y_train,epochs=50,batch_size = 32)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\athar\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 44/44 [==============================] - 13s 100ms/step - loss: 0.0207
# Epoch 2/50
# 44/44 [==============================] - 3s 68ms/step - loss: 0.0019
# Epoch 3/50
# 44/44 [==============================] - 3s 72ms/step - loss: 0.0016
# Epoch 4/50
# 44/44 [==============================] - 3s 74ms/step - loss: 0.0015
# Epoch 5/50
# 44/44 [==============================] - 3s 74ms/step - loss: 0.0014
# Epoch 6/50
# 44/44 [==============================] - 3s 76ms/step - loss: 0.0012
# Epoch 7/50
# 44/44 [==============================] - 4s 84ms/step - loss: 0.0013
# Epoch 8/50
# 44/44 [==============================] - 4s 94ms/step - loss: 0.0012
# Epoch 9/50
# 44/44 [==============================] - 4s 100ms/step - loss: 0.0010
# Epoch 10/50
# 44/44 [==============================] - 4s 88ms/step - loss: 0.0010
# Epoch 11/50
# 44/44 [==============================] - 3s 75ms/step - loss: 0.0011
# Epoch 12/50
# 44/44 [==============================] - 3s 79ms/step - loss: 8.8499e-04
# Epoch 13/50
# 44/44 [==============================] - 4s 82ms/step - loss: 8.2164e-04
# Epoch 14/50
# 44/44 [==============================] - 4s 82ms/step - loss: 7.9780e-04
# Epoch 15/50
# 44/44 [==============================] - 4s 80ms/step - loss: 8.4214e-04
# Epoch 16/50
# 44/44 [==============================] - 4s 82ms/step - loss: 7.7864e-04
# Epoch 17/50
# 44/44 [==============================] - 3s 74ms/step - loss: 9.2682e-04
# Epoch 18/50
# 44/44 [==============================] - 3s 66ms/step - loss: 7.8333e-04
# Epoch 19/50
# 44/44 [==============================] - 3s 75ms/step - loss: 7.2106e-04
# Epoch 20/50
# 44/44 [==============================] - 3s 71ms/step - loss: 6.6511e-04
# Epoch 21/50
# 44/44 [==============================] - 4s 82ms/step - loss: 6.6129e-04
# Epoch 22/50
# 44/44 [==============================] - 4s 83ms/step - loss: 6.7973e-04
# Epoch 23/50
# 44/44 [==============================] - 4s 79ms/step - loss: 6.0573e-04
# Epoch 24/50
# 44/44 [==============================] - 4s 79ms/step - loss: 6.1397e-04
# Epoch 25/50
# 44/44 [==============================] - 4s 94ms/step - loss: 5.8259e-04
# Epoch 26/50
# 44/44 [==============================] - 5s 106ms/step - loss: 6.3094e-04
# Epoch 27/50
# 44/44 [==============================] - 4s 88ms/step - loss: 5.4970e-04
# Epoch 28/50
# 44/44 [==============================] - 4s 88ms/step - loss: 5.1844e-04
# Epoch 29/50
# 44/44 [==============================] - 4s 86ms/step - loss: 6.0497e-04
# Epoch 30/50
# 44/44 [==============================] - 4s 85ms/step - loss: 4.7832e-04
# Epoch 31/50
# 44/44 [==============================] - 4s 86ms/step - loss: 5.9899e-04
# Epoch 32/50
# 44/44 [==============================] - 4s 91ms/step - loss: 4.9200e-04
# Epoch 33/50
# 44/44 [==============================] - 4s 97ms/step - loss: 5.4653e-04
# Epoch 34/50
# 44/44 [==============================] - 4s 94ms/step - loss: 4.8097e-04
# Epoch 35/50
# 44/44 [==============================] - 4s 87ms/step - loss: 4.4266e-04
# Epoch 36/50
# 44/44 [==============================] - 4s 86ms/step - loss: 4.4627e-04
# Epoch 37/50
# 44/44 [==============================] - 4s 89ms/step - loss: 4.6177e-04
# Epoch 38/50
# 44/44 [==============================] - 4s 88ms/step - loss: 4.5636e-04
# Epoch 39/50
# 44/44 [==============================] - 4s 89ms/step - loss: 4.7023e-04
# Epoch 40/50
# 44/44 [==============================] - 4s 88ms/step - loss: 4.4015e-04
# Epoch 41/50
# 44/44 [==============================] - 4s 93ms/step - loss: 3.8757e-04
# Epoch 42/50
# 44/44 [==============================] - 4s 99ms/step - loss: 3.9049e-04
# Epoch 43/50
# 44/44 [==============================] - 5s 107ms/step - loss: 4.8405e-04
# Epoch 44/50
# 44/44 [==============================] - 4s 89ms/step - loss: 4.2821e-04
# Epoch 45/50
# 44/44 [==============================] - 4s 91ms/step - loss: 3.7700e-04
# Epoch 46/50
# 44/44 [==============================] - 4s 92ms/step - loss: 3.8601e-04
# Epoch 47/50
# 44/44 [==============================] - 4s 94ms/step - loss: 3.6422e-04
# Epoch 48/50
# 44/44 [==============================] - 4s 93ms/step - loss: 3.6873e-04
# Epoch 49/50
# 44/44 [==============================] - 4s 95ms/step - loss: 4.1917e-04
# Epoch 50/50
# 44/44 [==============================] - 4s 94ms/step - loss: 4.2314e-04

# %%
test_data = scaled_data[training_data-60:,:]
X_test = []
Y_test = []
for i in range(60,len(test_data)):
    X_test.append(test_data[i-60:i,0:cols])
    Y_test.append(test_data[i, 0:cols])
X_test, Y_test = np.array(X_test), np.array(Y_test)
X_test = np.reshape(X_test,(X_test.shape[0],X_test.shape[1],cols))
X_test.shape,Y_test.shape
# Out:
# ((366, 60, 1), (366, 1))

# %%
prediction = model.predict(X_test)
prediction = scaler.inverse_transform(prediction)
prediction.shape
# Out:
# 12/12 [==============================] - 2s 21ms/step
# (366, 1)

# %%
Y_test = scaler.inverse_transform(Y_test)
rsme = np.sqrt(np.mean(Y_test-prediction)**2).round(2)
rsme
# Out:
# 417.69

# %%
output = pd.DataFrame(data={'predictions':prediction.flatten(),'Actuals':Y_test.flatten()})
output
# Out:
#       predictions       Actuals
# 0    16407.677734  16547.496094
# 1    16372.071289  16625.080078
# 2    16389.681641  16688.470703
# 3    16440.621094  16679.857422
# 4    16472.037109  16863.238281
# ..            ...           ...
# 361  42201.714844  43442.855469
# 362  42635.535156  42627.855469
# 363  42259.339844  42099.402344
# 364  41712.617188  42156.902344
# 365  41592.187500  42265.187500
#
# [366 rows x 2 columns]

# %%
to_row = int(len(df) * 0.8)
plt.figure(figsize = (15,9))
plt.grid(True)
data = df[to_row:].index
plt.plot(data,prediction,color='Green',linestyle='solid',label="BTC predicted value")
plt.plot(data,Y_test,color='red',label="BTC actual value")
plt.title('Bitcoin Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price(USD)')
plt.legend()
plt.show()

# %%
mae = np.mean(np.abs(prediction - Y_test))
mse = np.mean(np.square(prediction - Y_test))
rsme1 = np.sqrt(mse)
mape = np.mean(mae / Y_test) * 100
print("Mean Absolute Error: "+str(mae))   
print("Mean Squared Error: "+str(mse)) 
print("Root Mean Squared Error: "+str(rsme1)) 
print("Mean Absolute Percentage Error: "+str(mape),"%")
# Out:
# Mean Absolute Error: 587.5489908854166
# Mean Squared Error: 655774.4897547055
# Root Mean Squared Error: 809.7990428215543
# Mean Absolute Percentage Error: 2.121685144578985 %
